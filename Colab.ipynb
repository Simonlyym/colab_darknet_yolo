# %%
# !mv kaggle.json /root/.kaggle/
# !kaggle datasets download -d simonhay/safetyhelmetwearingdataset

# %%
# !unzip safetyhelmetwearingdataset
# !git clone https://github.com/Simonlyym/colab_darknet_yolo.git

# %%
# !mv SHWD/* darknet/VOCdevkit/VOC2007/

# %%
# %cd /content/darknet/
# !python3 voc_label.py
# !cat 2007_train.txt 2007_test.txt > train.txt
# Out:
# /content/darknet

# %%
# %cd /content/darknet
# !make

# %%
# 模型转化为参数
# %cd /content/darknet/
# !./darknet partial cfg/yolov3-tiny.cfg yolov3-tiny_20000+.backup yolov3-tiny.conv.15 15
# Out:
# /content/darknet
# layer     filters    size              input                output
#     0 conv     16  3 x 3 / 1   416 x 416 x   3   ->   416 x 416 x  16  0.150 BFLOPs
#     1 max          2 x 2 / 2   416 x 416 x  16   ->   208 x 208 x  16
#     2 conv     32  3 x 3 / 1   208 x 208 x  16   ->   208 x 208 x  32  0.399 BFLOPs
#     3 max          2 x 2 / 2   208 x 208 x  32   ->   104 x 104 x  32
#     4 conv     64  3 x 3 / 1   104 x 104 x  32   ->   104 x 104 x  64  0.399 BFLOPs
#     5 max          2 x 2 / 2   104 x 104 x  64   ->    52 x  52 x  64
#     6 conv    128  3 x 3 / 1    52 x  52 x  64   ->    52 x  52 x 128  0.399 BFLOPs
#     7 max          2 x 2 / 2    52 x  52 x 128   ->    26 x  26 x 128
#     8 conv    256  3 x 3 / 1    26 x  26 x 128   ->    26 x  26 x 256  0.399 BFLOPs
#     9 max          2 x 2 / 2    26 x  26 x 256   ->    13 x  13 x 256
#    10 conv    512  3 x 3 / 1    13 x  13 x 256   ->    13 x  13 x 512  0.399 BFLOPs
# ...

# %%
# 训练
# %cd /content/darknet/
# !./darknet detector train cfg/voc.data cfg/yolov3-tiny.cfg backup/yolov3-tiny_300.weights
# Out:
# /content/darknet
# yolov3-tiny
# layer     filters    size              input                output
#     0 conv     16  3 x 3 / 1   416 x 416 x   3   ->   416 x 416 x  16  0.150 BFLOPs
#     1 max          2 x 2 / 2   416 x 416 x  16   ->   208 x 208 x  16
#     2 conv     32  3 x 3 / 1   208 x 208 x  16   ->   208 x 208 x  32  0.399 BFLOPs
#     3 max          2 x 2 / 2   208 x 208 x  32   ->   104 x 104 x  32
#     4 conv     64  3 x 3 / 1   104 x 104 x  32   ->   104 x 104 x  64  0.399 BFLOPs
#     5 max          2 x 2 / 2   104 x 104 x  64   ->    52 x  52 x  64
#     6 conv    128  3 x 3 / 1    52 x  52 x  64   ->    52 x  52 x 128  0.399 BFLOPs
#     7 max          2 x 2 / 2    52 x  52 x 128   ->    26 x  26 x 128
#     8 conv    256  3 x 3 / 1    26 x  26 x 128   ->    26 x  26 x 256  0.399 BFLOPs
#     9 max          2 x 2 / 2    26 x  26 x 256   ->    13 x  13 x 256
#    10 conv    512  3 x 3 / 1    13 x  13 x 256   ->    13 x  13 x 512  0.399 BFLOPs
# ...

# %%
# 生成结果文件
# %cd /content/darknet/
# !./darknet detector valid cfg/voc.data cfg/yolov3-tiny.cfg backup/yolov3-tiny_300.weights -out S_

# %%
# 评估模型
# %cd /content/darknet/
# !mv restult/S_hat.txt restult/hat.txt
# !mv restult/S_person.txt restult/person.txt 
# !python2 compute_map.py

# %%
# 推送到github
# !git add .
# !git commit -m 'Add sample code'
# !git push origin master
